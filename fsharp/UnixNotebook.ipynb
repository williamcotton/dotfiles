# %%
#load "/Users/williamcotton/dotfiles/fsharp/Utils.fsx"

open Unix
open Jupyter

let dh = displayHelpers display HTML

# %%
Ok "pattern
    runner
    batter"
    |> grep "tt"
    |> awk """'{print $1 " " $1 " " $1}'"""
    |> echo
# Out:
# pattern pattern pattern
# batter batter batter

# %%
Ok "one,two,three,date
    9,2,3,2021-01
    4,5,9,2021-02
    7,3,2,2021-03"
    |> plt64 "[one, two, three], date { 
            bar 10px [solid red, solid green, solid blue] 
        }"
    |> function
        | Ok image64 -> dh.displayImage64 image64
        | Error e -> display(e) |> ignore
# Out:
# <img src="data:image/png;base64,...
# " />
